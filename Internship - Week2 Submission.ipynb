# %% [markdown]
# # Importing all required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the dataset

# %%
data=pd.read_csv(r"C:\Users\Workstation X\Desktop\ICT\Internship\credit.csv")

# %% [markdown]
# # Display first 6 rows

# %%
data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %% [markdown]
# # To display the columns

# %%
data.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %% [markdown]
# # To display the no:of rows and columns

# %%
data.shape
# Out:
# (100000, 28)

# %% [markdown]
#  There are 1,00,000 rows and 28 columns

# %% [markdown]
# # To display the basic information of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
## From the above output we can get an overall idea of the datatypes of each column. Also, there are no null/missing values

# %% [markdown]
# # To check the no:of unique values in a particular column

# %%
data['Credit_Score'].nunique()
# Out:
# 3

# %% [markdown]
# # To display the unique values

# %%
data['Credit_Score'].unique()
# Out:
# array(['Good', 'Standard', 'Poor'], dtype=object)

# %% [markdown]
# # To display the occurence of each unique value.

# %%
data['Credit_Score'].value_counts()
# Out:
# Standard    53174
# Poor        28998
# Good        17828
# Name: Credit_Score, dtype: int64

# %% [markdown]
# # Display the statistical information

# %%
data.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %% [markdown]
# # To get the correlation

# %%
data.corr()
# Out:
# C:\Users\Workstation X\AppData\Local\Temp\ipykernel_23416\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                 ID   Customer_ID         Month       Age  \
# ID                        1.000000  1.235872e-03  5.291503e-05  0.003338
# Customer_ID               0.001236  1.000000e+00 -6.660113e-17 -0.002172
# Month                     0.000053 -6.660113e-17  1.000000e+00  0.016990
# Age                       0.003338 -2.172258e-03  1.698955e-02  1.000000
# SSN                       0.011707  5.769305e-03 -1.557496e-16 -0.008411
# Annual_Income            -0.005357  1.076923e-02  1.530483e-17  0.091525
# Monthly_Inhand_Salary    -0.004792  1.019558e-02 -1.818625e-03  0.090636
# Num_Bank_Accounts         0.004826 -1.188701e-03  7.909795e-05 -0.190415
# ...

# %% [markdown]
# # Display the correlation matrix using heatmap

# %%
sns.heatmap(data.corr(), annot = True, cmap = 'rocket_r')
plt.xticks(rotation=45)
plt.title("Correlation Matrix")
#plt.figure(figsize=(30,15))
sns.set(rc={'figure.figsize':(20,10)})
plt.show()
# Out:
# C:\Users\Workstation X\AppData\Local\Temp\ipykernel_23416\1818352072.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot = True, cmap = 'rocket_r')

# %% [markdown]
# # To display the statistical information of categorical columns

# %%
data.describe(include='O')
# Out:
#             Name Occupation Type_of_Loan Credit_Mix Payment_of_Min_Amount  \
# count     100000     100000       100000     100000                100000
# unique     10128         15         6261          3                     3
# top     Jessicad     Lawyer      No Data   Standard                   Yes
# freq          48       7096        11408      45848                 52326
#
#                      Payment_Behaviour Credit_Score
# count                           100000       100000
# unique                               6            3
# top     Low_spent_Small_value_payments     Standard
# freq                             28616        53174

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Count plot of column 'Credit_Score'

# %%
sns.countplot(data, x='Credit_Score', hue='Credit_Score')
plt.show()
plt.figure(figsize=(10,5))
plt.tight_layout()

# %% [markdown]
# # Bar Plot of Age vs Annual Income

# %%
sns.barplot(data=data, x='Age', y= 'Annual_Income')
plt.xticks(rotation=45)
plt.figure(figsize=(15,5))

# %% [markdown]
# In a bar plot created using the seaborn library, the black lines at the end of each bar represent confidence intervals. These lines indicate the uncertainty or variability associated with each bar's height estimate.
#
# By default, seaborn's bar plot (sns.barplot) includes error bars representing a 95% confidence interval around the mean of each bar. The confidence interval provides a range within which we can be reasonably certain that the true population parameter (in this case, the mean) lies

# %%
## To check if age has an effect on annual income (without the ci)

sns.barplot(data=data, x='Age', y= 'Annual_Income', ci=None)
plt.xticks(rotation=45)
plt.figure(figsize=(20,10))
# Out:
# C:\Users\Workstation X\AppData\Local\Temp\ipykernel_23416\1462544774.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data, x='Age', y= 'Annual_Income', ci=None)

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(data=data, x='Age', y= 'Annual_Income')
# Out:
# <Axes: xlabel='Age', ylabel='Annual_Income'>

# %%
## The annual incme belowe 20 years of age is found to be less.

# %% [markdown]
# # Bar Plot of credit score vs age w.r.t Payment of min amt

# %%
sns.barplot(data=data, x='Age', y= 'Credit_Score', hue='Payment_of_Min_Amount', ci=None)
# Out:
# C:\Users\Workstation X\AppData\Local\Temp\ipykernel_23416\1673433748.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data, x='Age', y= 'Credit_Score', hue='Payment_of_Min_Amount', ci=None)
# <Axes: xlabel='Age', ylabel='Credit_Score'>

# %% [markdown]
# # Count Plot of Occupation w.r.t Credit Mix

# %%
plt.figure(figsize= (17,9))
sns.countplot(data=data,x="Occupation",hue="Credit_Mix")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# # Histogram of Age

# %%
sns.histplot(data=data, x='Age', bins=30, edgecolor='k')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
## The najority people are in the age of 30 to 40.

# %% [markdown]
# # Histograms of all numeric columns

# %%
data.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# # Count Plot of Credit mix w.r.t Credit score

# %%
plt.figure(figsize=[15,10])
sns.countplot(x='Credit_Mix',hue='Credit_Score',data=data)
# Out:
# <Axes: xlabel='Credit_Mix', ylabel='count'>

# %% [markdown]
# # Pre-processing Steps

# %% [markdown]
# # To check if there is any null values

# %%
data.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
## To display columns with missing values - just checking with another method
columns_with_missing_values = data.columns[data.isna().any()].tolist()

print("Columns with missing values:")
for column in columns_with_missing_values:
    print(column)
# Out:
# Columns with missing values:

# %% [markdown]
# # To check if there are duplicated rows

# %%
duplicate_rows = data[data.duplicated()]

# Display the duplicated rows
print("Duplicated Rows:")
print(duplicate_rows)
# Out:
# Duplicated Rows:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# # Outlier detection

# %% [markdown]
# # Box Plot

# %%
fig, ax = plt.subplots(ncols=6, nrows=4, figsize=(20, 10))
count = 0
ax = ax.flatten()

# Loop through each column in the DataFrame
for i, col in enumerate(data.columns):
    # Check if the column is numeric
    if data[col].dtype in ['int64', 'float64']:
        sns.boxplot(y=data[col], ax=ax[count])
        ax[count].set_title(f'{col}')
        #ax[count].yaxis.set_label_coords(0, 0)  # Adjust the label position
        count += 1
# Remove empty subplots if any
for i in range(count, len(ax)):
    fig.delaxes(ax[i])

plt.tight_layout(pad=0.8, w_pad=1.0, h_pad=5.0)
plt.suptitle("Box Plots", y=1.03)  # Adjust title position
plt.show()

# %%
data['Annual_Income'].mean()
# Out:
# 50505.12344879999

# %% [markdown]
# # Replacing the outliers with the log transformation method

# %%
# Columns with outliers
columns_with_outliers = ['Annual_Income', 'Monthly_Inhand_Salary', 'Delay_from_due_date','Changed_Credit_Limit','Num_Credit_Inquiries','Outstanding_Debt','Credit_Utilization_Ratio','Total_EMI_per_month','Amount_invested_monthly','Monthly_Balance']


# Dictionary to store boolean outliers for each column
#outliers_dict = {}

# Loop through each column
for column_name in columns_with_outliers:
    # Calculate the interquartile range (IQR)
    q1 = data[column_name].quantile(0.25)
    q3 = data[column_name].quantile(0.75)
    iqr = q3 - q1

    # Define the upper and lower bounds for outliers
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # Identify outliers in boolean format
    outliers = (data[column_name] < lower_bound) | (data[column_name] > upper_bound)

    # Store boolean outliers in the dictionary
    #outliers_dict[column_name] = outliers

    # Replace outliers with log-transformed values
    data[column_name] = np.log1p(data[column_name])

# Display boolean outliers for each column
#for column_name, outliers_boolean in outliers_dict.items():
    #print(f"Outliers for {column_name} (boolean format):\n{outliers_boolean}")

# Display the transformed DataFrame
data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       9.858235               7.509797                3.0  ...        Good
# 1       9.858235               7.509797                3.0  ...        Good
# 2       9.858235               7.509797                3.0  ...        Good
# 3       9.858235               7.509797                3.0  ...        Good
# 4       9.858235               7.509797                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %% [markdown]
# Log transformation is effective in reducing right-skewness, making the distribution more symmetric.
# It compresses the scale of large values, bringing them closer to the mean.
#
# Log transformation can magnify the differences between small values, making them more visible.
# Extreme values (outliers) in the original scale may become more pronounced in the log-transformed scale.
#
# The data contains zero values. Hence considered adding a small constant (e.g., 1) to the data before applying the log transformation (np.log1p is suitable for this purpose).

# %%
data['Annual_Income'].mean()
# Out:
# 10.536539708189764

# %%
data.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08      10.536540               8.045535           5.368820
# std    2.908267e+08       0.790548               0.800100           2.593314
# ...

# %%
# Display boolean outliers for each column
#for column_name, outliers_boolean in outliers_dict.items():
    #print(f"Outliers for {column_name} (boolean format):\n{outliers_boolean}")

# %%
# Display boolean outliers for each column
#for column_name, outliers_boolean in outliers_dict.items():
#    print(f"Outliers for {column_name} (boolean format):\n{outliers_boolean}")

    # Get the count of True and False values in the 'Income' column
#    income_outliers_count = outliers_boolean.value_counts()

    # Display the count of True and False values in the 'Income' column
#    print(f"Count of True (outliers) in {column_name}: {income_outliers_count[True]}")
#    print(f"Count of False (non-outliers) in {column_name}: {income_outliers_count[False]}")

# %%
fig, ax = plt.subplots(ncols=6, nrows=4, figsize=(20, 10))
count = 0
ax = ax.flatten()

# Loop through each column in the DataFrame
for i, col in enumerate(data.columns):
    # Check if the column is numeric
    if data[col].dtype in ['int64', 'float64']:
        sns.boxplot(y=data[col], ax=ax[count])
        ax[count].set_title(f'{col}')
        #ax[count].yaxis.set_label_coords(0, 0)  # Adjust the label position
        count += 1
# To remove empty subplots
for i in range(count, len(ax)):
    fig.delaxes(ax[i])

plt.tight_layout(pad=0.8, w_pad=1.0, h_pad=5.0)
plt.suptitle("Box Plots", y=1.03)  # Adjust title position
plt.show()

# %% [markdown]
# The appearance of outliers below the lower bound after log transformation is not uncommon, especially when dealing with data that includes zero values. It happens because the log transformation of values close to zero can result in negative values, and these might be identified as outliers based on traditional bounds.

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# List of categorical columns
categorical_columns = ['Type_of_Loan', 'Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour','Credit_Score']

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
for column in categorical_columns:
    if column in data.columns:
        data[column] = label_encoder.fit_transform(data[column])

# Display the DataFrame after label encoding
data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       9.858235               7.509797                3.0  ...           1
# 1       9.858235               7.509797                3.0  ...           1
# 2       9.858235               7.509797                3.0  ...           1
# 3       9.858235               7.509797                3.0  ...           1
# 4       9.858235               7.509797                3.0  ...           1
#
#    Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# ...

# %%
## Deleting few columns as it won't impact the dataset.

data.drop('ID', axis=1, inplace=True)
data.drop('Customer_ID', axis=1, inplace=True)
data.drop('Month', axis=1, inplace=True)
data.drop('Name', axis=1, inplace=True)
data.drop('Age', axis=1, inplace=True)
data.drop('SSN', axis=1, inplace=True)
data.drop('Occupation', axis=1, inplace=True)

data.head()
# Out:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       9.858235               7.509797                3.0              4.0
# 1       9.858235               7.509797                3.0              4.0
# 2       9.858235               7.509797                3.0              4.0
# 3       9.858235               7.509797                3.0              4.0
# 4       9.858235               7.509797                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  Type_of_Loan  Delay_from_due_date  \
# 0            3.0          4.0           128             1.386294
# 1            3.0          4.0           128             1.386294
# 2            3.0          4.0           128             1.386294
# 3            3.0          4.0           128             1.791759
# 4            3.0          4.0           128             1.945910
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  ...  Credit_Mix  \
# ...

# %% [markdown]
# # Normalizing

# %%
from sklearn.preprocessing import Normalizer

# Get the column name for the future use
feature_columns = data.iloc[:,:-1]
target_column=data['Credit_Score']

# Initiatiate and fit scaler
scaler = Normalizer()
data_scaled = scaler.fit_transform(feature_columns)

# Embedding the scaled data into the dataset
data_scaled_new = pd.DataFrame(data_scaled,columns=feature_columns.columns)

data_scaled_new.head()
# Out:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       0.033424               0.025462           0.010171         0.013562
# 1       0.033328               0.025388           0.010142         0.013523
# 2       0.033219               0.025306           0.010109         0.013479
# 3       0.033124               0.025233           0.010080         0.013440
# 4       0.033027               0.025159           0.010051         0.013401
#
#    Interest_Rate  Num_of_Loan  Type_of_Loan  Delay_from_due_date  \
# 0       0.010171     0.013562      0.433980             0.004700
# 1       0.010142     0.013523      0.432730             0.004687
# 2       0.010109     0.013479      0.431318             0.004671
# 3       0.010080     0.013440      0.430083             0.006020
# 4       0.010051     0.013401      0.428829             0.006519
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# ...

# %% [markdown]
# # Spliiting the data into training and test data

# %%
# Split the data into features and target

X=data_scaled_new
y=target_column

# %%
# Split the data into training and test data

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2, random_state=50)

# %% [markdown]
# # Classification

# %% [markdown]
# # 1. K-Nearest Neighbors (KNN)

# %%
# Fitting clasifier to the Training set
from sklearn.neighbors import KNeighborsClassifier

# Instantiate learning model (k = 3)
classifier = KNeighborsClassifier(n_neighbors=3)

# Fitting the model
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred_knn = classifier.predict(X_test)

# Evaluate the model

from sklearn.metrics import accuracy_score
accuracy_knn=accuracy_score(y_test,y_pred_knn)*100
print("Accuracy of our model is equal to " + str(round(accuracy_knn,2))+"%")
# Out:
# Accuracy of our model is equal to 80.64%

# %% [markdown]
# # 2. Support Vector Classification

# %%
from sklearn.svm import SVC

# Create and train a Support Vector Classifier (SVC)
svc_classifier = SVC() 
svc_classifier.fit(X_train, y_train)

# Make predictions on the test set
svc_predictions = svc_classifier.predict(X_test)

# Evaluate the accuracy of the classifier
from sklearn.metrics import accuracy_score 
svc_accuracy = accuracy_score(y_test, svc_predictions)*100 
print("Support Vector Classifier Accuracy:" + str(round(svc_accuracy,2))+"%")
# Out:
# Support Vector Classifier Accuracy:53.34%

# %% [markdown]
# # 3. Decision Tree Classifier

# %%
## Build Decision Tree Model

from sklearn.tree import DecisionTreeClassifier

# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="gini", max_depth=50)


# Train Decision Tree Classifer
clf.fit(X_train,y_train)

# Predict the response for test dataset
y_pred_dtc = clf.predict(X_test)


# Evaluating the model

from sklearn import metrics
acc_dtc= metrics.accuracy_score(y_test, y_pred_dtc)*100
print("Accuracy is "+str(round(acc_dtc,2))+"%")
# Out:
# Accuracy is 76.52%

# %% [markdown]
# # 4. Random Forest Classification

# %%
# import Random Forest classifier
from sklearn.ensemble import RandomForestClassifier
# instantiate the classifier
rfc = RandomForestClassifier(random_state=50)
# fit the model
rfc.fit(X_train, y_train)

# Predict the Test set results
y_pred_rfc = rfc.predict(X_test)


## Check accuracy score
from sklearn.metrics import accuracy_score

acc_rfc = accuracy_score(y_test,y_pred_rfc)
print('Model accuracy score: ',str(round(acc_rfc*100,2))+"%")
# Out:
# Model accuracy score:  83.12%

# %% [markdown]
# # 5. Ada Boost Classification

# %%
from sklearn.ensemble import AdaBoostClassifier

abc_model=AdaBoostClassifier(n_estimators=90)

# Train Decision Tree Classifer
abc_model.fit(X_train,y_train)

# Predict the response for test dataset
y_pred_abc_model = abc_model.predict(X_test)


# Evaluating the model

from sklearn import metrics
acc_abc= metrics.accuracy_score(y_test, y_pred_abc_model)*100
print("Accuracy is "+str(round(acc_abc,2))+"%")
# Out:
# Accuracy is 61.85%

# %% [markdown]
# # 6. Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

model= GaussianNB()

# Train Decision Tree Classifer
model.fit(X_train,y_train)

# Predict the response for test dataset
y_pred_model = model.predict(X_test)

# Evaluating the model
from sklearn import metrics 
acc_nb= metrics.accuracy_score(y_test, y_pred_model)*100 
print("Accuracy is "+str(round(acc_nb,2))+"%")
# Out:
# Accuracy is 23.57%
